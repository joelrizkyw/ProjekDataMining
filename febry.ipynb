# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Data yang digunakan berupa employability dari sebuah universitas.

# %%
df = pd.read_csv('./dataset/Placement_Data_Full_Class.csv')

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.isna().any()
# Out:
# sl_no             False
# gender            False
# ssc_p             False
# ssc_b             False
# hsc_p             False
# hsc_b             False
# hsc_s             False
# degree_p          False
# degree_t          False
# workex            False
# etest_p           False
# specialisation    False
# mba_p             False
# status            False
# salary             True
# dtype: bool

# %%
df.groupby('status')[['status', 'salary']].count()
# Out:
#             status  salary
# status
# Not Placed      67       0
# Placed         148     148

# %% [markdown]
# Salary dan sl_no (Serial Number) tidak digunakan dalam prediksi ini, karena tidak berpengaruh terhadap status penerimaan

# %%
df.drop(['salary', 'sl_no'], axis=1, inplace=True)
df
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status
# 0       No     55.0         Mkt&HR  58.80      Placed
# 1      Yes     86.5        Mkt&Fin  66.28      Placed
# 2       No     75.0        Mkt&Fin  57.80      Placed
# 3       No     66.0         Mkt&HR  59.43  Not Placed
# 4       No     96.8        Mkt&Fin  55.50      Placed
# ..     ...      ...            ...    ...         ...
# 210     No     91.0        Mkt&Fin  74.49      Placed
# 211     No     74.0        Mkt&Fin  53.62      Placed
# 212    Yes     59.0        Mkt&Fin  69.72      Placed
# 213     No     70.0         Mkt&HR  60.23      Placed
# 214     No     89.0         Mkt&HR  60.22  Not Placed
#
# [215 rows x 13 columns]

# %%
df['status'] = df.status.replace(['Placed', 'Not Placed'], [1, 0])

# %% [markdown]
# # Removing outlier using IQR technique

# %%
# Dataframe untuk status = 1 (Placed)
df_status_1 = df[df["status"] == 1].copy()

df_status_1
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 7        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status
# 0       No     55.0         Mkt&HR  58.80       1
# 1      Yes     86.5        Mkt&Fin  66.28       1
# 2       No     75.0        Mkt&Fin  57.80       1
# 4       No     96.8        Mkt&Fin  55.50       1
# 7      Yes     67.0        Mkt&Fin  62.14       1
# ..     ...      ...            ...    ...     ...
# 209     No     67.0        Mkt&Fin  56.49       1
# 210     No     91.0        Mkt&Fin  74.49       1
# 211     No     74.0        Mkt&Fin  53.62       1
# 212    Yes     59.0        Mkt&Fin  69.72       1
# 213     No     70.0         Mkt&HR  60.23       1
#
# [148 rows x 13 columns]

# %%
# Outlier detection untuk df_status_1
df_status_1.plot(kind = "box", subplots = True, sharey = False, figsize = (10, 6))

plt.subplots_adjust(wspace = 0.5)
plt.show()

# %%
# Dataframe untuk status = 0 (Not Placed)
df_status_0 = df[df["status"] == 0].copy()

df_status_0
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status
# 3       No    66.00         Mkt&HR  59.43       0
# 5      Yes    55.00        Mkt&Fin  51.58       0
# 6       No    74.28        Mkt&Fin  53.29       0
# 9       No    54.00        Mkt&Fin  52.21       0
# 12      No    62.00         Mkt&HR  65.04       0
# ..     ...      ...            ...    ...     ...
# 198     No    88.00         Mkt&HR  71.96       0
# 201     No    79.00         Mkt&HR  58.44       0
# 206     No    97.00        Mkt&Fin  53.39       0
# 208     No    92.66         Mkt&HR  62.92       0
# 214     No    89.00         Mkt&HR  60.22       0
#
# [67 rows x 13 columns]

# %%
# Outlier detection untuk df_status_0

df_status_0.plot(kind = "box", subplots = True, sharey = False, figsize = (10, 6))

plt.subplots_adjust(wspace = 0.5)
plt.show()

# %%
changed = True
while changed:
    changed = False
    for column in df_status_1.select_dtypes(include=np.number).columns:
        if(column != 'status'):
            q1 = df_status_1[column].quantile(0.25)
            q2 = df_status_1[column].median()
            q3 = df_status_1[column].quantile(0.75)
            iqr = q3 - q1
            max = q3 + (1.5 * iqr)
            min = q1 - (1.5 * iqr)
            if (df_status_1[column].loc[df_status_1[column] > max].any() or df_status_1[column].loc[df_status_1[column] < min].any()):
                df_status_1[column].loc[df_status_1[column] > max] = q2
                df_status_1[column].loc[df_status_1[column] < min] = q2
                changed = True

changed = True
while changed:
    changed = False
    for column in df_status_0.select_dtypes(include=np.number).columns:
        if(column != 'status'):
            q1 = df_status_0[column].quantile(0.25)
            q2 = df_status_0[column].median()
            q3 = df_status_0[column].quantile(0.75)
            iqr = q3 - q1
            max = q3 + (1.5 * iqr)
            min = q1 - (1.5 * iqr)
            if(df_status_0[column].loc[df_status_0[column] > max].any() or df_status_0[column].loc[df_status_0[column] < min].any()):
                df_status_0[column].loc[df_status_0[column] > max] = q2
                df_status_0[column].loc[df_status_0[column] < min] = q2
                changed = True
# Out:
# C:\Users\DarkMattz\AppData\Local\Temp\ipykernel_32540\4245190992.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_status_1[column].loc[df_status_1[column] > max] = q2
# C:\Users\DarkMattz\AppData\Local\Temp\ipykernel_32540\4245190992.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_status_1[column].loc[df_status_1[column] < min] = q2
# C:\Users\DarkMattz\AppData\Local\Temp\ipykernel_32540\4245190992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_status_0[column].loc[df_status_0[column] > max] = q2
# C:\Users\DarkMattz\AppData\Local\Temp\ipykernel_32540\4245190992.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_status_0[column].loc[df_status_0[column] < min] = q2

# %%
df_status_combined = pd.concat([df_status_1, df_status_0])

df_status_combined
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 7        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F  67.00  Central  70.00  Central  Commerce     65.00     Others
# 201      M  54.20  Central  63.00   Others   Science     58.00  Comm&Mgmt
# 206      M  41.00  Central  42.00  Central   Science     60.00  Comm&Mgmt
# 208      F  43.00  Central  60.00   Others   Science     65.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status
# 0       No    55.00         Mkt&HR  58.80       1
# 1      Yes    86.50        Mkt&Fin  66.28       1
# 2       No    75.00        Mkt&Fin  57.80       1
# 4       No    96.80        Mkt&Fin  55.50       1
# 7      Yes    67.00        Mkt&Fin  62.14       1
# ..     ...      ...            ...    ...     ...
# 198     No    88.00         Mkt&HR  71.96       0
# 201     No    79.00         Mkt&HR  58.44       0
# 206     No    97.00        Mkt&Fin  53.39       0
# 208     No    92.66         Mkt&HR  62.92       0
# 214     No    89.00         Mkt&HR  60.22       0
#
# [215 rows x 13 columns]

# %% [markdown]
# # Ubah data categorical menjadi numerical

# %%
list_column_categorical = list(df_status_combined.select_dtypes(exclude = np.number).columns.values)

for column_name in list_column_categorical:

    df_status_combined[column_name] = df_status_combined[column_name].astype("category")
    df_status_combined[column_name] = df_status_combined[column_name].cat.codes

# %% [markdown]
# # Normalisasi

# %%
std_scaler = StandardScaler()

scaled_data = std_scaler.fit_transform(df_status_combined.drop('status', axis=1))

df_combined_scaled = pd.DataFrame(scaled_data, columns = df_status_combined.columns.drop('status')).join(df_status_combined['status'])

df_combined_scaled
# Out:
#        gender     ssc_p     ssc_b     hsc_p     hsc_b     hsc_s  degree_p  \
# 0    0.739434 -0.028087  1.082459  2.386570  0.800763 -0.641955 -1.168257
# 1    0.739434  1.113369 -0.923823  1.174140  0.800763  1.083298  1.719957
# 2    0.739434 -0.213238 -0.923823  0.185631 -1.248809 -2.367207 -0.278663
# 3    0.739434  1.712332 -0.923823  0.721512 -1.248809 -0.641955  1.100206
# 4    0.739434  1.360545 -0.923823 -0.197141 -1.248809  1.083298  0.017868
# ..        ...       ...       ...       ...       ...       ...       ...
# 210 -1.352386 -0.028087 -0.923823  0.377017 -1.248809 -0.641955 -0.130398
# 211  0.739434 -1.213053 -0.923823 -0.292834  0.800763  1.083298 -1.168257
# 212  0.739434 -2.435049 -0.923823 -2.302387 -1.248809  1.083298 -0.871726
# 213 -1.352386 -2.249898 -0.923823 -0.579913  0.800763  1.083298 -0.130398
# 214  0.739434 -0.490964 -0.923823 -0.771299  0.800763  1.083298 -1.909585
#
#      degree_t    workex   etest_p  specialisation     mba_p  status
# 0    1.576284 -0.724446 -1.291091        1.123903 -0.597647       1
# 1    1.576284  1.380364  1.087157       -0.889757  0.687620       1
# 2   -0.675550 -0.724446  0.218908       -0.889757 -0.769474       1
# 3   -0.675550 -0.724446  1.864806       -0.889757 -1.164676       0
# 4    1.576284  1.380364 -0.385092       -0.889757 -0.023744       1
# ..        ...       ...       ...             ...       ...     ...
# 210  0.450367 -0.724446  1.200407        1.123903  1.663598       1
# 211 -0.675550 -0.724446  0.520907        1.123903 -0.659504       1
# 212 -0.675550 -0.724446  1.879906       -0.889757 -1.527231       1
# 213 -0.675550 -0.724446  1.552236        1.123903  0.110281       1
# 214 -0.675550 -0.724446  1.275907        1.123903 -0.353652       0
#
# [215 rows x 13 columns]

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df_status_combined, hue='status')

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df_status_combined.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scaling Data

# %%
df = df_combined_scaled

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['ssc_p', 'hsc_p', 'degree_p']], df['status'], test_size=0.3, random_state=42)

# %% [markdown]
# # Model

# %% [markdown]
# # KNN

# %% [markdown]
# # SVM

# %% [markdown]
# ## Untuned

# %%
untuned_svc = SVC(random_state=42)
untuned_svc.fit(X_train, y_train)
# Out:
# SVC(random_state=42)

# %%
print(classification_report(y_test, untuned_svc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.19      0.22        21
#            1       0.65      0.73      0.69        44
#
#     accuracy                           0.55        65
#    macro avg       0.45      0.46      0.45        65
# weighted avg       0.52      0.55      0.54        65

# %% [markdown]
# # Tuned

# %%
untuned_svc = SVC(C=1000, random_state=42)
untuned_svc.fit(X_train, y_train)
print(classification_report(y_test, untuned_svc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.19      0.22        21
#            1       0.65      0.73      0.69        44
#
#     accuracy                           0.55        65
#    macro avg       0.45      0.46      0.45        65
# weighted avg       0.52      0.55      0.54        65

# %% [markdown]
# # AdaBoost
